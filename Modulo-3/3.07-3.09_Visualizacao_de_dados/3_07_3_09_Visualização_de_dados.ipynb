# %% [markdown]
# > Projeto Desenvolve <br>
# Programação Intermediária com Python <br>
# Profa. Camila Laranjeira (mila@projetodesenvolve.com.br) <br>
#
# # Introdução a visualização de dados
#
# Visualização de dados é um tema que envolve muitas disciplinas, principalmente:
# * **Interface Humano-Computador** (IHC): Visualizar dados é transformar uma pilha de dados em algo que faça sentido à primeira vista. Portanto, envolve o design de elementos visuais que sejam facilmente navegáveis e interpretáveis pelos usuários. Um exemplo claro são as visualizações interativas, onde o aspecto usabilidade se torna essencial.
# * **Estatística**: Produzir gráficos é um aspecto profundamente enraizado na estatística, pois representar dados visualmente requer aplicar resumos estatísticos eficientes para comunicar o que se deseja de forma precisa e significativa.
#
# Nesta introdução, vamos pincelar por cima ambas as áreas. Porém, caso você se interesse pela área, terá que estudar muito mais cada um desses aspectos. Aqui a gente vai focar em quatro bibliotecas python, cada qual com suas vantagens e desvantagens, para produzir visualizações. São elas.
#
# * **Matplotlib**: É a biblioteca base para visualizações em Python, estando presente em outras bibliotecas que veremos aqui, como Seaborn e o próprio Pandas. Com uma capacidade ampla de personalização, vai te permitir fazer gráficos exatamente como você desejar.
#
# * **Seaborn**: Construída sobre Matplotlib, Seaborn simplifica a criação de gráficos atrativos e informativos, sendo muito bem intergrada com DataFrames do Pandas. Necessita do apoio do matplotlib para permitir maior personalização, mas define de forma transparente uma série de propriedades do gráfico, inclusive transformando e processando os dados.
#
# * **Plotly**: Conhecida por suas capacidades interativas, Plotly é uma biblioteca poderosa para criar gráficos dinâmicos. Com Plotly, é possível gerar gráficos 3D, mapas geográficos e dashboards interativos, tornando-a ideal para apresentações e aplicações web.
#
# * **Pandas**: Embora seja principalmente uma biblioteca para manipulação de dados, Pandas também possui uma interface de visualização que te conecta com funcionalidades de outras bibliotecas, como os próprios matplotlib ou plotly. Com Pandas, é possível criar rapidamente gráficos a partir de DataFrames.

# %% [markdown]
# ## Matplotlib
#
# O Matplotlib é uma biblioteca amplamente utilizada em Python para a criação de gráficos e visualizações de dados.
#
# #### **Flexibilidade** 👍
# Permite a criação de uma ampla variedade de gráficos, desde simples gráficos de linha até complexos gráficos 3D.
#
# #### **Personalização** 👍
# Possibilita ajustes detalhados em todos os aspectos dos gráficos, como cores, estilos de linha, e rótulos. Todo o controle nas suas mãos :)
#
# #### **Compatibilidade** 👍
# Incorporado em bibliotecas populares de análise de dados, como NumPy e Pandas, facilitando a integração em fluxos de trabalho de ciência de dados.
#
# #### **Curva de aprendizado** 👎
# Curva de aprendizado relativamente íngreme para iniciantes, por possuir muitas funcionalidades e opções.
#
# #### **Verboso** 👎
# A criação de gráficos altamente personalizados pode exigir muitas linhas de código.

# %% [markdown]
# ### Estilos
#
# Um estilo base padroniza aspectos como cores, fontes, estilos de linha, presença de grid, etc., garantindo que todas as visualizações sigam um esquema visual coerente e agradável.
#
# Estilos disponíveis: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# <img src="https://matplotlib.org/stable/_images/sphx_glr_style_sheets_reference_001_2_00x.png" height=150>
#
# <img src="https://matplotlib.org/stable/_images/sphx_glr_style_sheets_reference_005_2_00x.png" height=150>
#
# <img src="https://matplotlib.org/stable/_images/sphx_glr_style_sheets_reference_008_2_00x.png" height=150>
#
# <img src="https://matplotlib.org/stable/_images/sphx_glr_style_sheets_reference_015_2_00x.png" height=150>

# %%
import matplotlib
matplotlib.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# O módulo `pyplot` é o mais importante da biblioteca Matplotlib. É lá que ficam os métodos de criação e personalização de visualizações. A literatura convenciona o import do `matplotlib.pyplot` com o apelido `plt`
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
# O comando `%matplotlib inline` no ambiente Jupyter permite que os gráficos sejam exibidos logo após a célula onde foram criados. Caso contrário, é necessário invocar o comando `plt.show()` para exibir a visualização.
# * [Saiba mais sobre comandos mágicos que você pode usar em notebooks Jupyter e Colab](https://ipython.readthedocs.io/en/stable/interactive/magics.html).
#
# ```python
# %matplotlib inline
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')

# %% [markdown]
# ### Galeria de plots
#
# * Tipos de plots (resumo geral): https://matplotlib.org/stable/plot_types/index.html
# * Galeria completa de plots: https://matplotlib.org/2.0.2/gallery.html

# %% [markdown]
# ### Plot de linha
#
# Um dos métodos mais utilizados do pyplot (aqui chamado de `plt`) é o método `plot`, que permite a criação de gráficos de linha a partir de valores fornecidos para o eixo x e y, que representam os **pontos a serem conectados pela linha do gráfico**.
#
# Ao invocar `plt.plot(x, y)`, estamos criando uma nova figura com os dados `x` no eixo horizontal e `y` no eixo vertical, apresentados visualmente como uma linha. Graças ao comando mágico utilizado anteriormente, figuras produzidas em uma célula serão exibidas ao final, com ou sem invocar `plt.show()`. Porém, ao remover essa chamada, o Jupyter assume o comportamento padrão de apresentar o objeto de retorno da última instrução contida na célula.

# %%
# Plotando uma senoide
x = np.arange(0, 3 * np.pi, 0.2)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# **Propriedades do plot de linha**
#
# Você pode transformá-lo em uma linha tracejada, ou até incluir símbolos que demarcam cada ponto `(x, y)` das entradas, além da linha que os conecta.
#
# * Marcadores: https://matplotlib.org/stable/api/markers_api.html
# * Estilos de linha: https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# * Lista completa de propriedades de linha: https://matplotlib.org/stable/tutorials/pyplot.html#controlling-line-properties

# %%
dados = np.array([[5., 7., 9., 8.],  [14., 20., 23., 27.], [25., 22., 15., 12.]])
X = np.arange(dados.shape[1])

marcadores = ['s', 'o', 'v']
linhas = ['--', ':', '-.']
for i in range(0, dados.shape[0]):
	plt.plot(
		   X, dados[i],
		   marker=marcadores[i],
		   linestyle=linhas[i])

# %% [markdown]
# ### Múltiplos plots e propriedades
#
# Ao invocar múltiplas vezes algum método que produz figuras (como o `plt.plot()`), todas as visualizações são sobrepostas na mesma figura, facilitando a comparação visual entre diversas funções ou dados. Esse é o comportamento padrão do matplotlib, mas você tem a alternativa de criar explícitamente múltiplas figuras (veremos a seguir).
#
# É possível personalizar o gráfico para melhor representar os dados e facilitar a interpretação visual. A seguir apresentamos as principais propriedades que podemos personalizar em um gráfico.
#
# * `plt.xlabel('rótulo do eixo x')`: Define o rótulo do eixo x.
# * `plt.ylabel('rótulo do eixo y')`: Define o rótulo do eixo y.
# * `plt.title('Seno, cosseno e 0.01x2')`: Define o título do gráfico.
# * `plt.legend(['Seno', 'Cosseno', '0.01x2'], loc='upper right')`: Adiciona uma legenda ao gráfico, com a localização especificada no canto superior direito.
# * `plt.text(2.55, 1., r'Minhas funções')`: Adiciona texto em uma posição específica do gráfico, no ponto (2.55, 1.0).
# * `plt.axis([-1, 11, -1.2, 1.8])`: Define os limites dos eixos x e y (x0, x1, y0, y1).
# * `plt.grid(True)`: Ativa a grade no gráfico para melhor visualização e leitura dos dados.

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_001x2 = 0.01 * x**2

# Múltiplos plots incluídos na mesma figura (comportamento padrão)
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.plot(x, y_001x2)

# Principais propriedades
plt.xlabel('rotulo do eixo x')
plt.ylabel('rotulo do eixo y')
plt.title('Seno, cosseno e 0.01x2')
plt.legend(['Seno', 'Cosseno', '0.01x2'], loc='upper right')
plt.text(2.55, 1., r'Minhas funções') # x, y, texto
plt.axis([-1, 11, -1.2, 1.8]) #x0, x1, y0, y1
plt.grid(True)
plt.show()

# %% [markdown]
# ### `figure()`, gráfico de barras e cores
#
# Você acabou de ver múltiplos plots na mesma figura. E se eu quiser cada plot em uma figura? Bom, basta criar uma nova figura com o comando a seguir. A partir deste ponto, novas chamadas de plot serão feitas na nova figura. A propriedade opcional `figsize` permite definir a largura e altura da visualização (isso deve ser feito com cautela pois pode alterar a percepção sobre os dados).
# ```python
# plt.figure(figsize=(w, h))
# ```
#
# Criaremos de exemplo um **gráfico de barras**. O comando `plt.bar(x, y)` produz um gráfico de barras **vertical**, onde `x` representa as categorias ou rótulos das barras, e `y` representa os valores correspondentes a cada categoria. Já o comando `plt.barh(y, x)` cria um gráfico de barras **horizontal**, invertendo a disposição dos eixos: `y` representa as categorias ou rótulos das barras e `x` os valores correspondentes.
#
# ```python
# plt.bar(x, y) # vertical
# plt.barh(y, x) # horizontal
# ```
#
# Nessa célula também, personalizamos a cor dos elementos que representam os nossos dados, nesse caso, as barras. Isso é feito através do parâmetro `color`, que pode ser uma única representação de cor (a qual será atribuída a todas as barras) ou uma lista de cores, uma para cada elemento visual (uma por barra). As cores podem ser:
#
# * Cores padrão: um único caractere representando as cores base da biblioteca.
# ```python
# { 'b': blue, 'g': green, 'r': red, 'c': cyan, 'm': magenta, 'y': yellow, 'k': black, 'w': white }
# ```
#
# * Cores hexadecimal: Códigos hexadecimais na forma `#RRGGBB`, onde `RR`, `GG`, e `BB` são valores hexadecimais que representam a intensidade de vermelho, verde e azul, respectivamente. (Lembre-se: hexadecimal é a base numérica com `16` valores, onde cada número pode variar de `0` a `F`, equivalente a `0` a `15` em decimal).
# ```
# 	#FF7F50
# ```
#
# * Tupla de cor: Tupla `(r, g, b)` que especifica as intensidades de vermelho, verde e azul, cada uma variando de 0 a 1.
# ```
# (1, 0.5, 0.5)
# ```

# %%
data = [5., 25., 50., 20.]
names= ['Valor 1', 'Valor 2', 'Valor 3', 'Valor 4']
plt.bar(names, data, color='k')

plt.figure(figsize=(6, 3)) #figsize(largura, altura) em polegadas
plt.barh(names, data, color=['r', 'g', 'b', (1, 0.5, 0.5)])

plt.figure(figsize=(6, 3)) #figsize(largura, altura) em polegadas
plt.barh(range(len(data)), data, color='#FF7F50')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Eixos
# O objeto da figura, no entanto, pode ser algo muito mais complexo. A figura é toda a área onde os elementos gráficos são desenhados, como uma folha de papel em branco onde você vai desenhar seus gráficos. Você pode ajustar as propriedades da figura inteira, como seu tamanho e resolução.
#
# Além de múltiplas figuras, podemos trabalhar também com múltiplos **eixos**(*axes*). Apesar de você conhecer a palavra "eixo" como as dimensões de um único gráfico, **aqui ela representa subplots**, ou seja, cada eixo é uma subfigura onde os dados podem ser plotados. Os eixos possuem seus próprios rótulos, marcações de grade, título, etc.
#
# > O conceito de eixo no escopo de subplots do Matplotlib está relacionado ao conceito de "[pequenos múltiplos](https://en.wikipedia.org/wiki/Small_multiple)" de visualização de dados, quando separamos os dados em subgrupos para comparar as estatísticas de cada subgrupo.
#
# Podemos criar uma figura com múltiplos eixos através do comando a seguir, que retorna não só a referência à figura inteira, como também ao array de eixos.
# ```python
# fig, axs = plt.subplots(nrows=1, ncols=3, sharex=False, sharey=False, figsize=(15, 4))
# ```
# * `nrows=1, ncols=3`: cria uma grade de 1 linha e 3 colunas, resultando em três eixos (subplots) lado a lado.
# * `sharex=False, sharey=False`: indica que os eixos x e y não são compartilhados entre os subplots. Ou seja, cada eixo terá seus próprios limites em x e em y.
# * `figsize=(15, 4)`: define o tamanho da figura inteira (todos os 3 eixos) como 15 polegadas de largura e 4 polegadas de altura.
#
# Note que as definições de propriedade a partir de um eixo (e não mais a partir da figura inteira) são métodos de nomes distintos, como
#
# ```python
# axs[0].set_title('Título')
# ```
#
# Quando trabalhamos com o plot comum, com um único eixo, usamos o equivalente:
# ```python
# plt.title('Título')
# ```

# %%
data = [5., 25., 50., 20.]
names= ['Valor 1', 'Valor 2', 'Valor 3', 'Valor 4']

fig, axs = plt.subplots(nrows=1, ncols=3, sharex=False, sharey=False, figsize=(15, 4))
axs[0].bar(names, data)
axs[1].barh(names, data, color='r')
axs[2].barh(range(len(data)), data, color='#FF7F50')

# muda como definir as propriedades
axs[0].set_title('Figura Vertical com rótulos')
axs[1].set_title('Figura Horizontal com rótulos')
axs[2].set_title('Figura Horizontal com índices numéricos')
plt.show()

# %% [markdown]
# A função `plt.subplot` é uma abordagem mais antiga que permite adicionar subplots manualmente, especificando a posição de cada subplot dentro da grade.  Cada subplot é adicionado especificando a posição com três números: número total de linhas da figura, número total de colunas e índice do subplot que desejamos popular. Esses índices variam de `1` ao `N` desejado.

# %%
fig = plt.figure(figsize=(15, 4))

ax0 = plt.subplot(131) # total de linhas, total de colunas e índice atual
ax0.bar(names, data)

ax1 = plt.subplot(132) # total de linhas, total de colunas e índice atual
ax1.barh(names, data)

ax2 = plt.subplot(133) # total de linhas, total de colunas e índice atual
ax2.barh(range(len(data)), data)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Múltiplas barras
#
# O código abaixo cria um gráfico de múltiplas barras, ou seja, temos 3 atributos que desejamos comparar na mesma figura dispondo as barras lado a lado. Para evitar sobreposições, basta manipular 2 atributos:
# * Deslocar o eixo x de cada plot
# * Alterar a largura da barra (garantindo que a soma de larguras seja `< 1`)
#
# **Propriedade `xticks`**<br>
# Neste caso, desejamos um último rótulo para cada grupo de barras, isso pode ser feito personalizando o atributo `xticks`. *Ticks* pode ser livremente traduzido do inglês como "marcação", `xticks` portanto são as marcações do eixo x.
#
# ```python
# plt.xticks(np.arange(0, 4)+0.25, colunas)
# ```
# * `np.arange(0, 4) + 0.25`: Calcula as posições dos rótulos. O deslocamento de 0.25 é adicionado para centralizar os rótulos sob os grupos de barras.
# * `colunas`: Os rótulos de texto que aparecem no eixo x.

# %%
dados = np.array([[5., 7., 9., 8.],  [14., 20., 23., 27.], [25., 22., 15., 12.]])
X = np.arange(4)
plt.bar(X + 0.00, dados[0], color = 'b', width = 0.267)
plt.bar(X + 0.267, dados[1], color = 'g', width = 0.267)
plt.bar(X + 0.533, dados[2], color = '#FF7F50', width = 0.267)

# Propriedades
colunas = ['2013', '2014', '2015', '2016']
plt.xlabel('rótulo do eixo x')
plt.ylabel('rótulo do eixo y')
plt.title('gráfico de multiplas barras')
plt.legend(['Legenda 1', 'Legenda 2', 'Legenda 3'])
plt.xticks(np.arange(0, 4)+0.25, colunas)
plt.show()

# %%
# Fazendo com laços
X = np.arange(dados.shape[1])
cores = ['b', 'g', '#FF7F50']
compr = 0.8/(dados.shape[0])
for i in range(0, dados.shape[0]):
    plt.bar(X + compr*i, dados[i], color=cores[i], width=compr)
plt.show()

# %% [markdown]
# ### Barras empilhadas
#
# O atributo bottom no método plt.bar é utilizado para especificar a posição inicial das barras no eixo y, permitindo que as barras sejam empilhadas uma sobre a outra. No comando `plt.bar(X, B, color='y', bottom=A)`, as barras representadas pelos dados B são desenhadas começando a partir da altura definida pelos valores de A.

# %%
A = [5., 30., 45., 17.]
B = [5., 25., 50., 55.]
X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'y', bottom = A)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Trabalhando com DataFrames
#
# O Matplotlib é capaz de trabalhar com as séries de um DataFrame do Pandas (*lembra que internamente elas são arrays Numpy?*), facilitando a criação de visualizações a partir de dados tabulares. No exemplo a seguir, utilizamos um conjunto de dados de câncer de mama disponível na biblioteca sklearn para demonstrar como criar um histograma com Matplotlib.
#
# **Histograma**<br>
# O histograma é uma forma de visualização que agrupa os dados em intervalos (**bins**) e mostra a frequência de valores em cada intervalo. No exemplo abaixo, o histograma agrupa automaticamente os valores da série 'mean radius' em 10 intervalos. Para plotar histogramas, temos:
#
# ```python
# plt.hist(dados, bins = 10)
# ```

# %%
from sklearn.datasets import load_breast_cancer
breast_cancer = load_breast_cancer()
print(data.feature_names)
print(data.target_names)

df = pd.DataFrame(breast_cancer.data, columns=breast_cancer.feature_names)
df['target'] = data.target
display(df.head())

mean_radius = breast_cancer.data[0]
plt.hist(df['mean radius'], bins = 10)
plt.show()
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# ['malignant' 'benign']
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# ...

# %% [markdown]
# ### Gráfico de Dispersão
#
# O gráfico de dispersão, ou scatter plot, é uma ferramenta gráfica utilizada para visualizar a relação entre duas variáveis quantitativas. No Matplotlib, o comando plt.scatter(x, y) é usado para criar este tipo de gráfico, onde x e y representam as variáveis nos eixos horizontal e vertical, respectivamente. Cada ponto no gráfico representa uma observação do conjunto de dados, permitindo identificar padrões, tendências, correlações e outliers entre as duas variáveis.
#
# **Tamanho, Cores e colormaps**<br>
# No comando a seguir, definimos além dos dados, os seguintes parâmetros:
# * O parâmetro `c` (*color*) permite definir as cores dos pontos no gráfico. Pode ser um único valor válido de cor, aplicando a mesma cor a todos os pontos, ou uma série de valores específicos para cada ponto. O argumento `c=df['target']` usa os valores da coluna `target` para determinar a cor de cada ponto. Isso facilita a visualização desse atributo como uma terceira dimensão, e como ele varia em relação às duas variáveis principais.
# * O atributo `cmap` (*colormap*) especifica o mapeamento de cores que será utilizado. O argumento `cmap='coolwarm_r'` aplica o colormap chamado `coolwarm_r` (`_r` indica a versão invertida).
#     * Colormaps disponíveis: https://matplotlib.org/stable/users/explain/colors/colormaps.html
# * O atributo `s` (*size*) define o tamanho dos pontos no gráfico de dispersão. Pode ser um único número, aplicando o mesmo tamanho a todos os pontos, ou uma série de valores, onde cada valor especifica o tamanho de um ponto individualmente.
#
# Explore [na documentação](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) outras propriedades do gráfico de dispersão.

# %%
fig = plt.scatter(df['mean radius'], df['mean area'],
            ### cor         # tamanho
            c=df['target'], s=df['worst area']/10,
            cmap='coolwarm_r', edgecolors='k')

plt.legend(handles=fig.legend_elements()[0], labels=['Maligno', 'Benigno'])

# %% [markdown]
# ### `imshow()`
#
# O método `imshow` é utilizado para exibir uma matriz (array) como uma imagem. Isso significa que os valores da matriz são interpretados como intensidades de cores, e a matriz é exibida como uma imagem colorida.
#
# ```python
# plt.imshow(dados) # dados é um array 2D
# ```
#
# Na célula a seguir, criamos uma base de dados simples com as máximas de temperatura de algumas capitais em 2023, para entender a utilidade desse tipo de visualização.

# %%
temperatura={'Salvador': [31,31,31,30,29,28,28,28,28,29,29,30],
             'Belo Horizonte': [30,30,29,28,26,26,26,27,29,30,29,29],
             'Macapá': [31,31,31,32,32,32,33,34,34,34,34,33],
             'Porto Alegre': [31,31,29,27,23,21,20,22,23,26,28,30]}
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago',
         'Set', 'Out', 'Nov', 'Dez']

temp_df = pd.DataFrame(temperatura, index=meses)
display(temp_df)
# Out:
#      Salvador  Belo Horizonte  Macapá  Porto Alegre
# Jan        31              30      31            31
# Fev        31              30      31            31
# Mar        31              29      31            29
# Abr        30              28      32            27
# Mai        29              26      32            23
# Jun        28              26      32            21
# Jul        28              26      33            20
# Ago        28              27      34            22
# Set        28              29      34            23
# Out        29              30      34            26
# Nov        29              29      34            28
# Dez        30              29      33            30

# %% [markdown]
# A seguir, extraímos a matriz numpy a partir do DataFrame criado de modo que os dados já estão organizados de maneira que linhas e colunas tem um significado claro (linhas são meses, colunas são cidades). Para melhor visualização, escolhemos plotar a transposta dessa matriz.
#
# **Colorbar**<br>
# A propriedade colorbar adiciona uma barra de cores à imagem gerada por imshow. A barra de cores serve como uma legenda para a imagem, indicando a correspondência entre as cores e os valores da matriz.

# %%
plt.imshow(temp_df.to_numpy().T)
plt.colorbar(label="°C", orientation="horizontal")

plt.grid(False)
plt.xticks(np.arange(len(temp_df.index)), temp_df.index)
plt.xlabel('Meses')
plt.yticks(np.arange(len(temp_df.columns)), temp_df.columns)
plt.ylabel('Capitais')
plt.title('Temperatura máxima ao longo de 2023')
plt.show()

# %% [markdown]
# Imagens nada mais são do que matrizes numéricas, onde cada elemento da matriz é uma intensidade de cor. Portanto podemos utilizar o `plt.imshow()` também para visualizar arquivos de imagem. Usaremos o auxílio da biblioteca Scikit-Image para carregar a imagem.

# %%
from skimage import io

img = io.imread("https://framerusercontent.com/images/LHg3C8DpIUydH4hegW9Dz9nrdg.png")
print(type(img), img.shape, '\n', img[:5,:1,:])
plt.imshow(img)
plt.grid(False)
# Out:
# <class 'numpy.ndarray'> (1604, 2400, 3)
#  [[[ 9 11 25]]
#
#  [[ 9 11 25]]
#
#  [[ 9 11 25]]
#
#  [[ 9 11 25]]
#
#  [[ 9 11 25]]]

# %% [markdown]
# #### Exemplo mais completo
#
# Vamos avaliar as variações de temperatura por latitude e por mês para o ano de 2014. Usaremos a biblioteca `xarray` que já nos fornece esses dados tratados (para latitudes so norte do globo). A biblioteca permite carregar os dados como DataFrames, o que facilita bastante a nossa interação com a base :)

# %%
import xarray as xr
airtemps = xr.tutorial.open_dataset('air_temperature').air.sel(lon=250.0).to_dataframe().drop('lon', axis=1)
display(airtemps)
# Out:
#                                  air
# time                lat
# 2013-01-01 00:00:00 75.0  246.500000
#                     72.5  242.000000
#                     70.0  240.389999
#                     67.5  242.699997
#                     65.0  247.299988
# ...                              ...
# 2014-12-31 18:00:00 25.0  294.589996
#                     22.5  296.290009
#                     20.0  296.089996
#                     17.5  297.989990
#                     15.0  299.190002
#
# [73000 rows x 1 columns]

# %% [markdown]
# Para que a nossa visualização não fique com informação demais (difícil de interpretar), isolamos apenas amostras de 2014, agregando valores coletados no mesmo mês e na mesma latitude. A função de agregação utilizada é `max`, ou seja, pegamos sempre a maior temperatura coletada.

# %%
# pegando só valores de 2014
airtemps = airtemps[airtemps.index.get_level_values('time').year == 2014]
# agrupando por mês e por latitude e agregando a média dos valores
airtemps = airtemps.groupby([airtemps.index.get_level_values('time').month, 'lat']).max()

display(airtemps)
# Out:
#                   air
# time lat
# 1    15.0  300.399994
#      17.5  300.100006
#      20.0  298.699982
#      22.5  298.500000
#      25.0  300.199982
# ...               ...
# 12   65.0  268.000000
#      67.5  266.290009
#      70.0  260.489990
#      72.5  254.189987
#      75.0  254.689987
#
# [300 rows x 1 columns]

# %% [markdown]
# Os dados ainda não são exatamente o que a gente quer, já que se extrairmos o array numpy da série `air`, teremos um array unidmensional sem a separação das dimensões "mês" e "latitude". Isso pode ser resolvido de inúmeras maneiras, desde usando a função `unstack` para remover um dos níveis do `MultiIndex` (transformando-o em colunas do DataFrame), até a opção que escolhemos, extrair o array numpy e redimensioná-lo.
#
# Agora sim, com uma matriz de `meses x latitudes`, faz sentido exibir com o comando `plt.imshow()`.
#
# > O que podemos interpretar nessa visualização?

# %%
latitudes = airtemps.index.get_level_values('lat').unique()
meses     = airtemps.index.get_level_values('time').unique()
matriz_valores = airtemps['air'].values.reshape(len(meses), len(latitudes))

plt.figure(figsize=(10, 10))
plt.imshow(matriz_valores.T[::-1], cmap='coolwarm')

plt.title('Temperatura do ar no norte global')
plt.colorbar()
plt.yticks(np.arange(len(latitudes)), latitudes[::-1])
plt.grid(False)
plt.show()

# %% [markdown]
# ## Seaborn
#
#
# #### **Bem integrado com o Pandas** 👍
# Seaborn trabalha de maneira intuitiva com DataFrames do Pandas, facilitando a criação de gráficos diretamente a partir das colunas do DataFrame. Ao especificar as colunas do DataFrame como parâmetros para os eixos (x, y), Seaborn simplifica a plotagem dos dados sem a necessidade de extraí-los manualmente.
#
# #### **Plots mais bonitos e completos com menos esforço** 👍
# O seaborn extrai automaticamente do DataFrame informações de propriedade, como título, rótulos de dimensão, marcadores, etc., que no Matplotlib teriam que ser incluídos manualmente. Seus métodos de plot também possuem muitos parâmetros interessantes, como estimadores estatísticos, reduzindo (muito) o número de linhas necessárias para criar um bom gráfico.
#
# #### **Integrado com o Matplotlib** 👍👎
# Ainda precisamos do conhecimento de matplotlib e suas propriedades para configurar as visualizações. Apesar do Seaborn fazer muitas coisas no automático, em alguns momentos precisamos da flexibilidade do matplotlib para que customizações específicas.
#
# #### **Ferramenteiro** 👎
# Sua tendência de automatizar muitas configurações pode resultar em códigos menos legíveis e de mais difícil customização. Além disso, para tirar o máximo proveito do Seaborn é necessário ter um bom conhecimento de sua ampla caixa de ferramentas, com funcionalidades nem sempre intuitivas.

# %% [markdown]
# Antes de usar o seaborn, você deve instalá-lo. Aqui no Jupyter, podemos usar comandos de terminal precedendo-os pela exclamação (`!`).

# %%
# !python -m pip install seaborn

# %% [markdown]
# ### Estética
#
# Tutorial "[Controlando atributos de estética](https://seaborn.pydata.org/tutorial/aesthetics.html)".
#
# ```python
# seaborn.set_theme(context='notebook', style='darkgrid', palette='deep', ...)
# ```
#
# * `context`: `'notebook'`, `'paper',` `'talk'`, `'poster'` ([Entenda o atributo contexto](https://seaborn.pydata.org/generated/seaborn.plotting_context.html#seaborn.plotting_context))
# * `style`: `'dark'`, `'white'`, `'darkgrid'`, `'whitegrid'`, `'ticks'` (mas também aceita a personalização via matplotlib - `plt.style.use(...)` )
# * `palette`: [Veja as paletas de cores disponíveis](https://seaborn.pydata.org/tutorial/color_palettes.html).

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sns.set_theme(context='notebook', style='darkgrid')

# plt.style.use('dark_background')
sns.barplot(x=['Barra 1', 'Barra 2'], y=[3, 7])
# Out:
# <Axes: >

# %% [markdown]
# ### Galeria
#
# * Galeria: https://seaborn.pydata.org/examples/index.html
# * Overview: https://seaborn.pydata.org/tutorial/function_overview.html
#
# <img src="https://seaborn.pydata.org/_images/function_overview_8_0.png" height=300>
#
# Assim como o matplotlib, também existe uma convenção de apelido para importar o Seaborn, neste caso `sns`.
# ```python
# import seaborn as sns
# ```
#
# Nesse primeiro exemplo vemos a simplicidade de acessar colunas de um dataframe a partir de métodos de plot do Seaborn. Por fim usamos o comando `plt.show()` pelas mesmas razões que o utilizamos até agora, para evitar que o objeto de retorno da última instrução seja impresso após a célula.

# %%
tips = sns.load_dataset("tips")
display(tips)

sns.barplot(
    data=tips, x="day", y="tip",
    estimator="max", errorbar=None
)

plt.title('Gorjeta máxima por dia da semana')
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# A sintaxe das propriedades no Seaborn é semelhante à do Matplotlib, o que facilita a transição entre as duas bibliotecas. Através do método `.set` podemos definir atributos como:
#
# * `title`: Define o título do gráfico.
# * `xlabel`, `ylabel`: Define os rótulos dos eixos X e Y.
# * `xlim`,  `ylim`: Define os limites dos eixos X e Y.
# * `xscale`, `yscale`: Define a escala dos eixo X e Y (por exemplo, 'linear', 'log').
# * `xticks`, `yticks`: Define a localização dos marcadores dos eixos X e Y.
# * `xticklabels`, `yticklabels`: Define os rótulos dos marcadores dos eixos X e Y.
#
# No entanto, há algumas diferenças, como a maneira de definir paletas de cores. No Matplotlib, usamos *colormaps* com o parâmetro `cmap`, enquanto no Seaborn usamos o atributo `palette`.
#
# * Lembrando: paletas disponíveis - https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
(
   sns.scatterplot(
        data=tips, x="total_bill", y="tip",
        # cor      # estilo
        hue="day", style="time",
        palette='deep'
   ).set(
        title="Análise de gorjetas",
        xlabel="Valor da conta",
        ylabel="Valor da gorjeta",
        ylim=(0,11), xlim=(0, 60),
        yticks=np.arange(0,11, 2),
        xticks=np.arange(0,60,10),
        yticklabels=[''] + [f'R${x:.2f}' for x in np.arange(0,11,2)[1:]],
        xticklabels=[''] + [f'R${x:.2f}' for x in np.arange(0,60,10)[1:]],
    )
)

plt.legend()
plt.show()

# %% [markdown]
# ### Múltiplos plots
#
# Além dos eixos (x, y) também podemos visualizar direta ou indiretamente outras colunas do DataFrame de entrada através de parâmetros adicionais. Esses parâmetros são utilizados para dividir os dados em subgrupos, e criar um subplot com as estatísticas de cada um dos subgrupos.
#
# O `lineplot` por exemplo possui os parâmetros:
# * `hue`: A maioria dos gráficos permite realizar sobrepor múltiplos plots com diferentes cores. Com esse parâmetro dizemos qual dimensão vai determinar a variação de cores do plot. Geralmente utiliza-se um atributo categórico.
# * `style`: Mais específico do `lineplot`, este parâmetro permite alterar o estilo da linha do gráfico de acordo com uma dimensão específica, também é geralmente um atributo categórico.

# %%
fmri = sns.load_dataset("fmri")
fmri.loc[:, 'timepoint'] = fmri.timepoint.astype(int)
display(fmri)

(
    sns.lineplot(data=fmri, x="timepoint", y="signal",
                hue='region', style='event',
                palette='bright',
                errorbar=None
    )
    .set(
        title="Ressonância magnética",
        xlabel='Instante da coleta',
    )
)

timepoints = sorted(fmri.timepoint.unique())
plt.xticks(
    np.arange(len(timepoints)),
    [f'{(t+1)*5}s' for t in timepoints],
    rotation=45,
)

plt.show()
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# Já para gráficos de distribuição, também temos o seguinte atributo:
#
# * `multiple`: `'layer'`, `'dodge'`, `'stack'`, `'fill'`. Uma vez que `hue` é definido, podemos informar como desejamos agregar os subplots na mesma figura.

# %%
penguins = sns.load_dataset("penguins")
display(penguins)

sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="dodge")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Também podemos criar figuras com múltiplos "eixos" (no sentido de múltiplas subfiguras) facilmente através dos parâmetros:
# * `row`: Plota em diferentes linhas as estatísticas que cada subgrupo do atributo selecionado.
# * `col`: Plota em diferentes colunas as estatísticas que cada subgrupo do atributo selecionado.
# * `col_wrap`: Estabelece um limite máximo de colunas, quebrando o grid de visualizações em múltiplas linhas. Utilizado em conjunto com o parâmetro `col`.

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %% [markdown]
# ### Axes
#
# Também podemos utilizar o nosso velho conhecido `plt.subplots` para criar múltiplas figuras. Métodos de plot no seaborn possuem o parâmetro `ax`, onde podemos definir em qual eixo (de um subplot do matplotlib) queremos desenhar o gráfico especificado.

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %% [markdown]
# ### FacetGrids
#
# Quando definimos um dos atributos `row` ou `col` para produzir subplots, o resultado é um objeto do tipo `seaborn.axisgrid.FacetGrid`. Esse objeto facilita a criação e a manipulação de múltiplos gráficos (plots) organizados em uma estrutura de grade (grid). Podemos invocar explícitamente esse tipo de dado.
# * Tutorial "[Construindo estruturas de multi-plot em grid](https://seaborn.pydata.org/tutorial/axis_grids.html)"
#
# Ao definir o `FacetGrid`, já informamos a base de dados utilizada para dar suporte à definição dos atributos que definem os subconjuntos do grid. No exemplo a seguir, definimos o grid a partir dos dados de pinguim, separando as visualizações em colunas a partir do atributo `species`.
#
# Com o método `map` do objeto `FacetGrid` criado, podemos aplicar funções de plotagem (como `sns.histplot`) a cada subset de dado.
# ```
# FacetGrid.map(func, *args, **kwargs)
# ```
# * O primeiro parâmetro `func` é o método de plotagem desejado
# * Depois, temos um conjunto de parâmetros posicionais `*args` que devem ser nomes de colunas do DataFrame fornecido ao `FacetGrid`,
# * Por fim, os `*kwargs` (*keyword arguments*) são atributos nomeados direcionados para o método de plotagem (quais parâmetros aquele plot aceita?)

# %%
g = sns.FacetGrid(penguins, col="species")
g.map(sns.histplot,     # func
      "bill_length_mm", # args
      kde=True          # kwargs
)

# %% [markdown]
# Atributos row, col e hue, além de propriedades da figura

# %%
g = sns.FacetGrid(penguins, col="island", hue="species",
                height=4, aspect=.8, sharex=True, sharey=True)
g.map(sns.barplot,               # func
      "body_mass_g", "species",  # args
      width=0.5, orient='h'      # kwargs
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Vejamos outro exemplo, incluindo o atributo `col_wrap` para uma grande quantidade de subplots.

# %%
fmri = sns.load_dataset("fmri")
fmri.loc[:, 'timepoint'] = fmri.timepoint.astype(int)
display(fmri)

g = sns.FacetGrid(fmri, col="subject", col_wrap=4, hue="region", palette='deep')
g.map(sns.lineplot, "timepoint", "signal")
g.add_legend()
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# ### Gráficos que combinam múltiplas visualizações
#
# * o `sns.pairplot` é uma ferramenta interessnte para ter uma visão geral dos seus dados. Ele permite criar uma matriz de gráficos de dispersão para cada par de variáveis numéricas, facilitando a visualização de padrões e correlações entre variáveis diferentes.
#     * Atributos `kind` `(‘scatter’ | ‘kde’ | ‘hist’ | ‘reg’)` e `diag_kind`  `(‘auto’ | ‘hist’ | ‘kde’ | None)` definem o tipo do gráfico que será plotado para cada par, seja entre pares de atributos, ou distribuições marginais na diagonal.
#     * Note que ele demora a produzir um resultado! São muitos gráficos para calcular e renderizar.
#
# * Ja o `sns.jointplot` pode ser usado para criar gráficos conjuntos que mostram a relação entre duas variáveis, complementados por histogramas das distribuições marginais.
#    * Atributo `kind` `(“scatter” | “kde” | “hist” | “hex” | “reg” | “resid”)` define o tipo do gráfico a ser plotado.

# %%
sns.pairplot(data=penguins, hue="species")

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm",
             hue="species", kind="scatter",)

# %% [markdown]
# ## Plotly
#
# #### **Visualizações interativas** 👍
# Plotly é uma biblioteca gráfica de código aberto que facilita a criação de visualizações interativas. Não só os gráficos possuem recursos nativos de interatividade como *mouse hover* (passar o mouse) para consultar os dados brutos, como você pode criar controles customizados de interatividade como botões, sliders e eventos de clique.
#
# #### **Integração com Pandas e Numpy** 👍
# Bem integrado com Pandas e Numpy, trabalha de maneira versátil com dados de diferentes naturezas. Além de ser um dos backends disponíveis para as funções de plot nativas do Pandas.
#
# #### **Ideal para Web** 👍
# Pela sua natureza interativa, é ideal para aplicações web (como dashboards por exemplo!). Seus objetos de figura podem ser diretamente importados em frameworks de aplicação web (Dash, Streamlit, ChartStudio), como também permite exportar o código html da figura para integração externa com qualquer ferramenta.
#
# #### **Desempenho** 👎
# Gráficos com muitos dados podem ser lentos para renderizar e interagir. Além disso, pode gerar arquivos HTML muito grandes, crescendo consideravelmente a sua aplicação.

# %% [markdown]
# ### Estética
#
# O Plotly permite a personalização de temas e templates para uniformizar a aparência dos gráficos. Na [documentação](https://plotly.com/python/templates/) você encontra a representação visual dos principais temas.

# %%
import plotly.io as pio
pio.templates.default = "plotly"

print(pio.templates)
print(pio.templates["plotly"].layout)
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']
#
# Layout({
#     'annotationdefaults': {'arrowcolor': '#2a3f5f', 'arrowhead': 0, 'arrowwidth': 1},
#     'autotypenumbers': 'strict',
#     'coloraxis': {'colorbar': {'outlinewidth': 0, 'ticks': ''}},
#     'colorscale': {'diverging': [[0, '#8e0152'], [0.1, '#c51b7d'], [0.2,
#                                  '#de77ae'], [0.3, '#f1b6da'], [0.4, '#fde0ef'],
#                                  [0.5, '#f7f7f7'], [0.6, '#e6f5d0'], [0.7,
#                                  '#b8e186'], [0.8, '#7fbc41'], [0.9, '#4d9221'],
#                                  [1, '#276419']],
#                    'sequential': [[0.0, '#0d0887'], [0.1111111111111111,
# ...

# %% [markdown]
# ### Galeria de plots
#
# Na [galeria de plots](https://plotly.com/python/) do Plotly, você encontrará tutoriais que utilizam dois diferentes módulos: **Plotly Express e Plotly Graph Objects**. Os tutoriais geralmente* começam com Plotly Express, pela facilidade para criar visualizações básicas com poucas linhas de código. Em seguida é apresentado o Graph Objects para customizações mais detalhadas e controle granular sobre cada aspecto do gráfico. Aqui faremos de maneira similar.
#
# * Galeria completa: https://plotly.com/python/
# * *Há casos em que o recurso só está disponível para o Plotly Graph Objects, como os gráficos [Gauge](https://plotly.com/python/gauge-charts/) para plot de métricas.
#
# Também usaremos muito o módulo de dados do Plotly para carregar DataFrames simples já contidos na biblioteca.
# * [Plotly data package](https://plotly.com/python-api-reference/generated/plotly.express.data.html)
#
# <img src="https://drive.google.com/uc?id=1QN4Eq6256iLizTCMZaEsMA-IaLD0pSIZ" width=650>

# %%
import plotly.express as px
import plotly.graph_objects as go

sa_countries = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',  'Peru',
                'Ecuador', 'Paraguay', 'Uruguay', 'Venezuela']

df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# #### Plotly Express
# Neste exemplo, com uma única chamada de função do Plotly Express, você pode gerar um gráfico de linha para os países Brasil, Uruguai e Peru, colorindo automaticamente as linhas por país e adicionando um título ao gráfico. Note que trabalhamos com o objeto DataFrame, acessando suas colunas através dos outros parâmetros da função (assim como aprendemos com Seaborn).
#
# > Tire um momento pra fuçar o gráfico e ver as interações nativamente disponíveis (mouse hover, zoom, pan, clique na legenda, seleção de área, etc...)

# %%
fig = px.line(df[df.country.isin(sa_countries)],
            x="year", y="lifeExp", color='country',
            title='Expectativa de vida ao longo dos anos'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Plotly Graph Objects
# Com Graph Objects, você cria um gráfico de linha para os mesmos países, mas com maior controle sobre o processo. Adiciona traços separadamente para cada país usando um loop, permitindo personalizações específicas para cada traço, como estilos de linha e cores. Após adicionar os traços, você pode atualizar o layout do gráfico para ajustar o título, eixos, e outros elementos de forma mais granular.
#
# Note que, ao criar o gráfico trabalhamos apenas com os objetos `pd.Series` do DataFrame, que internamente são arrays Numpy.

# %%
fig = go.Figure() # cria a figura
for country in sa_countries: # pra cada linha que eu quero plotar

    df_ = df[df.country == country] # filtra por país
    # adiciona uma nova linha
    fig.add_trace(
        # px.line
        go.Scatter(x=df_['year'], y=df_['lifeExp'], name=country)
    )

# definição de propriedades
fig.update_layout(title='Expectativa de vida ao longo dos anos')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Por que usar Graph Objects então?
#
# Faça um experimento: encontre o Brasil no gráfico anterior. Ainda que a gente melhore o esquema de cores ou customize as linhas e os marcadores, são muitos traços para encontrar facilmente uma instância desejada. Assumindo que o objetivo da visualização é destacar os dados Brasileiros dentro da América do Sul, ter controle sobre cada traço individualmente facilita a customização de um elemento específico.
# > Não ficou tão bonito, mas é só um exemplo né? 🤗
#
# Usando Graph Objects você também se habitua a usar métodos essenciais como o `update_layout`, nosso próximo assunto :)

# %%
fig = go.Figure()
for country in sa_countries:
    df_ = df[df.country == country]
    if country == 'Brazil':
        data = go.Scatter(x=df_['year'], y=df_['lifeExp'], name=country,
                          line_color='black ', line_width=5, marker_size=10)
    else:
        data = go.Scatter(x=df_['year'], y=df_['lifeExp'], name=country, )
    fig.add_trace(data)

fig.update_layout(title='Expectativa de vida ao longo dos anos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Personalização Básica
# Usando plotly express, muitos recursos de personalização estão disponíveis como parâmetros da função de plot. Vale a pena fuçar a documentação do plot que você deseja para explorar as customizações disponíveis (por exemplo: [documentação do plot de barras](https://plotly.com/python-api-reference/generated/plotly.express.bar.html)).

# %%
fig = px.bar(df[df.country=='Brazil'], x='year', y='pop', color='lifeExp',
             title ="População do Brasil ao longo dos anos", width=800,
             ## quais dados estarão no mouse hover?
             hover_data=['lifeExp', 'gdpPercap'],
             ## qual o apelido das dimensões?
             labels={'pop':'População',
                     'lifeExp': 'Exp. de vida',
                     'gdpPercap': 'PIB per capita',
                     'year': 'Ano',},

)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Porém, o método `update_layout` de objetos `Figure` (veja a [documentação](https://plotly.com/python/reference/layout/)) oferece possibilidades muito mais completas para personalização da nossa figura, incluindo fonte, espaçamento, configurações de legenda, etc. Em casos em que trabalhamos diretamente com Graph Objects (sem usar o Plotly Express) é através desse método que definimos até mesmo as coisas mais simples.
#
# Em ambos os casos (funções do `px` ou `update_layout`), o Plotly oferece um facilitador de sintaxe interessante. Os atributos podem ser configurados de duas maneiras:
# * sintaxe de dicionário: os atributos são internamente organizados em dicionários que podemos acessar diretamente.
# * `snake_case`: O uso do caracter `_` (underline) para agregar chaves dos dicionários.

# %%
fig = px.bar(df[df.country=='Brazil'], x='year', y='pop', color='lifeExp', width=800)

# sintaxe de dicionário
fig.update_layout(
    title="População do Brasil ao longo dos anos",
    xaxis={'title': "Ano"},
    yaxis={'title': "População"},
    font=dict(
        family="Courier New, monospace",
        size=16,
        color="RebeccaPurple"
    )
)

# sintaxe snake_case
fig.update_layout(
    title="População do Brasil ao longo dos anos",
    xaxis_title = "Ano",
    yaxis_title = "População",
    font_family="Courier New, monospace",
    font_size=16,
    font_color="RebeccaPurple"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Subplots
#
# O Plotly Express oferece recursos que facilitam a criação de múltiplos plots em uma mesma figura, incluindo a adição de gráficos marginais utilizando atributos como marginal_x. Esses recursos são particularmente úteis em gráficos de distribuição e dispersão (scatter), permitindo visualizar dados adicionais.

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species",
           marginal_y="violin", marginal_x="box", template="ggplot2", width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Também temos o já conhecido `facet`, nossos **pequenos múltiplots**, também disponíveis no Plotly Express. Nessa visualização, plotamos o mesmo dado dividido em subgrupos. Os atributos são:
# * `facet_row`: Recebe uma coluna do DataFrame para organizar os gráficos em múltiplas linhas, cada uma correspondendo a uma categoria ou valor único da variável.
# * `facet_col`: Recebe uma coluna do DataFrame para organizar os gráficos em múltiplas colunas, cada uma correspondendo a uma categoria ou valor único da variável.
# * `facet_col_wrap`: Define o número máximo de colunas, quebrando em novas linhas e criando um grid de visualizações.

# %%
df = px.data.gapminder().query("year==2007")
fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", hover_name="country",
                facet_col="continent", color="continent",
                log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Mas a forma genérica de criar subplots é através do módulo `subplots` do Plotly, mais especificamente sua função `make_subplots`. Ela funciona de maneira similar ao que aprendemos com Graph Objects, ou seja, adicionando novos traços, porém cada traço possui um indicador da linha e da coluna onde deve ser visualizado.

# %%
from plotly.subplots import make_subplots

df = px.data.iris()

# Criando subplots
fig = make_subplots(rows=1, cols=2, subplot_titles=("Gráfico 1", "Gráfico 2"))

# Adicionando traços aos subplots
fig.add_trace(go.Scatter(x=df['sepal_width'], y=df['sepal_length'], mode='markers'), row=1, col=1)
fig.add_trace(go.Scatter(x=df['petal_width'], y=df['petal_length'], mode='markers'), row=1, col=2)

fig.update_layout(title="Subplots Exemplo", width=900, showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# O exemplo a seguir [veio da documentação](https://plotly.com/python/mixed-subplots/) e apresenta subplots mistos, sem nenhuma relação um com o outro, para mostrar a forma mais genérica de se criar múltiplos plots na mesma figura.

# %%
import pandas as pd

df = pd.read_csv(
    "https://raw.githubusercontent.com/plotly/datasets/master/volcano_db.csv",
    encoding="iso-8859-1",
)
freq = df.Country.value_counts().reset_index()
df_v = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/volcano.csv")

## Criando a figura com subplots
fig = make_subplots(
    rows=1, cols=2,
    column_widths=[0.5, 0.5],

    ## por padrão considera-se um tipo xy de gráfico
    specs=[[{"type": "scattergeo"}, {"type": "bar"}]]
)

# Add scattergeo globe map of volcano locations
fig.add_trace(
    go.Scattergeo(lat=df["Latitude"],
                  lon=df["Longitude"],
                  mode="markers",
                  hoverinfo="text",
                  showlegend=False,
                  marker=dict(color="crimson", size=4, opacity=0.8)),
    row=1, col=1
)

# Update geo subplot properties
fig.update_geos(
    projection_type="orthographic",
    landcolor="white",
    oceancolor="MidnightBlue",
    showocean=True,
    lakecolor="LightBlue"
)

# Add locations bar chart
fig.add_trace(
    go.Bar(y=freq["count"][0:10],x=freq["Country"][0:10], marker=dict(color="crimson"), showlegend=False),
    row=1, col=2
)
fig.update_xaxes(tickangle=45)

fig.update_layout(height=400, width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Interatividade
#
# * Galeria de controles: https://plotly.com/python/#controls
# * Click Events: https://plotly.com/python/click-events/
#
# <img src="https://drive.google.com/uc?id=1wKO2hNBLcPBETrpQ1GB-854LhPjlRWgj" width=650>

# %% [markdown]
# #### Sliders no plotly express
#
# Plotly Express fornece sliders, mas com animação implícita usando o método "animate". O botão de reprodução de animação pode ser omitido removendo updatemenus no layout.
#
# A adição de sliders customizados se encontra no [tutorial completo do Plotly](https://plotly.com/python/sliders/).

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])

# fig["layout"].pop("updatemenus") # optional, drop animation buttons
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Botões e Menu Dropdown
#
# Ambos os recursos de botão e menu dropdown (ou drop em qualquer direção) usam do parâmetro `updatemenus` do método `update_layout`. Seu parâmetro é uma lista de dicionários, onde cada dicionário é um menu que se deseja adicionar. O que distingue um menu dropdown de um botão é o atributo `type` desse dicionário.
#
# Cada botão tem um parâmetro chamado `method` que define o tipo de alteração que será feita no gráfico. Suas opções são:
#
# * "**restyle**": modificar dados ou atributos de dados
# * "**relayout**": modificar atributos de layout
# * "**update**": modificar dados e atributos de layout; combinação de "restyle" e "relayout"
#
#
# > Tutorial botões: https://plotly.com/python/custom-buttons/ <br>
# Tutorial dropdown menu: https://plotly.com/python/dropdowns/

# %%
df = px.data.gapminder()
fig = px.bar(df[df.country=='Argentina'], x='year', y='pop', color='lifeExp',
             title="População ao longo dos anos: Argentina",)

# sintaxe de dicionário
fig.update_layout(
    xaxis={'title': "Ano"},
    yaxis={'title': "População"},
    font=dict(
        family="Courier New, monospace",
        size=16,
        color="RebeccaPurple"
    )
)

# Adicionar botão de interatividade para alterar o país
fig.update_layout(
    updatemenus=[
        ### Menu dropdown de países
        dict(
            direction="down",
            buttons=list([
                dict(
                    args=[
                    # dicionário de alterações de dados
                    {"x": [df[df['country']==country]['year']],
                    "y": [df[df['country'] == country]['pop']],
                    },
                    # dicionário de alterações de layout
                    {"title": f"População ao longo dos anos: {country}"
                    }],
                    label=str(country),
                    method="update"
                ) for country in sa_countries
            ]),
            showactive=True,
        ),

        ### Botões de tipo de gráfico
        dict(
            type="buttons",
            direction='down',
            buttons=list([
                dict(
                    args=[{"type": grafico}],
                    label=grafico,
                    method='restyle',
                ) for grafico in ['bar', 'scatter']
            ]),
            showactive=True,
            x=-0.07,
            y=0.85

        )
    ],
    # Rangeslider
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
    ),
    height=600, width=900
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Dash em 20 minutos :)
#
# > https://dash.plotly.com/tutorial
#
# Exemplos: https://dash-example-index.herokuapp.com/
